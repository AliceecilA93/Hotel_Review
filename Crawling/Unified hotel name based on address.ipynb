# %%
import pandas as pd

df_hotel = pd.read_csv('리뷰통합.csv')
df_hotel
# Out:
#         Unnamed: 0       name  \
# 0                0  제주 샤모니리조트
# 1                1  제주 샤모니리조트
# 2                2  제주 샤모니리조트
# 3                3  제주 샤모니리조트
# 4                4  제주 샤모니리조트
# ...            ...        ...
# 222478      222478   한화리조트 제주
# 222479      222479   한화리조트 제주
# 222480      222480   한화리조트 제주
# 222481      222481   한화리조트 제주
# 222482      222482   한화리조트 제주
#
#                                                    review  \
# 0       침구도 수건도 청소상태도 모두 너무 깔끔하고\n수압! 짱 두피맛사지가 됩니다\n조용...
# 1       세탁기와  전자레인지도 다 있고.. 방도 따뜻하니 좋았어요. 직원분들도 너무 세심하...
# 2                                              가성비가 좋았어요.
# 3       저렴한 가격에 편하게 잘 묵고 갑니다 직원분들이 진짜 친절하시고  로비 1층에 편의...
# 4                                            침구가 깨끗하고 좋아요
# ...                                                   ...
# 222478  직원들도 친절했어요..\n지역상 외출할 때 관광지랑은 좀 떨어져 있어서 그게 좀 불...
# 222479  일단 호텔에서 일하시는 분들이 참 친절하십니다. 거기다가 부대시설도 참 잘 갖춰져 ...
# 222480  확실히 리조트쪽 기온이 더 춥네요.\n우동*덴과 가까워요.\n불편함없이 잘 지냈어요...
# 222481  시설도 괜찮았고  일하시는 모든분들이 너무많이 친절하십니다\n단점은 위치 하나뿐이네...
# 222482                                          ['만족합니다']
#
#                                addr    site
# 0            제주특별자치도 서귀포시 강정동  1338  데일리 호텔
# 1            제주특별자치도 서귀포시 강정동  1338  데일리 호텔
# 2            제주특별자치도 서귀포시 강정동  1338  데일리 호텔
# 3            제주특별자치도 서귀포시 강정동  1338  데일리 호텔
# 4            제주특별자치도 서귀포시 강정동  1338  데일리 호텔
# ...                             ...     ...
# 222478  제주특별자치도 제주시 회천동  3-16 한화리조트    여기어때
# 222479  제주특별자치도 제주시 회천동  3-16 한화리조트    여기어때
# 222480  제주특별자치도 제주시 회천동  3-16 한화리조트    여기어때
# 222481  제주특별자치도 제주시 회천동  3-16 한화리조트    여기어때
# 222482  제주특별자치도 제주시 회천동  3-16 한화리조트     야놀자
#
# [222483 rows x 5 columns]

# %%
df_hotel[df_hotel['name'] == '윈스토리 호텔 서귀포']
# Out:
#        Unnamed: 0         name  \
# 43065       43065  윈스토리 호텔 서귀포
# 43066       43066  윈스토리 호텔 서귀포
# 43067       43067  윈스토리 호텔 서귀포
# 43068       43068  윈스토리 호텔 서귀포
# 43069       43069  윈스토리 호텔 서귀포
# ...           ...          ...
# 46365       46365  윈스토리 호텔 서귀포
# 46366       46366  윈스토리 호텔 서귀포
# 46367       46367  윈스토리 호텔 서귀포
# 46368       46368  윈스토리 호텔 서귀포
# 46369       46369  윈스토리 호텔 서귀포
#
#                                                   review  \
# 43065                                   괜찮았습니다 조식은 조금 실망
# 43066                            치약은 무료로 준비해주시면 좋았을거 같아요
# 43067  다 좋았는데 방안의 에어컨이 작동하면 너무 시끄러웠던것 같아요 그것 빼곤 다 만족합...
# 43068                      침구류도 깨끗하고 침대도 푹신하고 너무 잘쉬다가요^^
# 43069                                  방도깨끗하고 직원분들도 친절굳굳
# ...                                                  ...
# 46365  ['정말 창문 앞이 바다에요 ㅋㅋ ', '사장님 완전 친절하시고 대박!', '롯데리...
# 46366  ['제주도 여행중 머물렀던 숙소중 가장 좋았습니다. 세탁기도 있고, 냉장고도 크고 ...
# 46367                               ['시설 완전 좋습니다 진짜 !!']
# 46368                                       ['가격대비 좋아요']
# 46369                          ['전화가 잘 안터지는거 빼고는 괜찮았어요']
#
#                                     addr    site
# 43065            제주특별자치도 서귀포시 서귀동  294-6  데일리 호텔
# 43066            제주특별자치도 서귀포시 서귀동  294-6  데일리 호텔
# 43067            제주특별자치도 서귀포시 서귀동  294-6  데일리 호텔
# 43068            제주특별자치도 서귀포시 서귀동  294-6  데일리 호텔
# 43069            제주특별자치도 서귀포시 서귀동  294-6  데일리 호텔
# ...                                  ...     ...
# 46365  제주특별자치도 서귀포시 서귀동  318-17 호텔 윈 스토리     야놀자
# 46366  제주특별자치도 서귀포시 서귀동  318-17 호텔 윈 스토리     야놀자
# 46367  제주특별자치도 서귀포시 서귀동  318-17 호텔 윈 스토리     야놀자
# 46368  제주특별자치도 서귀포시 서귀동  318-17 호텔 윈 스토리     야놀자
# 46369  제주특별자치도 서귀포시 서귀동  318-17 호텔 윈 스토리     야놀자
#
# [1288 rows x 5 columns]

# %%
# 불필요한 열 삭제
df_hotel = df_hotel.drop('Unnamed: 0',axis=1)

# %%
addr = []
for i in df_hotel['addr']:
  addr.append(i)

list_addr=[]
for j in addr:
  if(j not in list_addr):
    list_addr.append(j)

list_addr# 가지고 올 이름의 기준이 될 주소값을 저장
# Out:
# ['제주특별자치도 서귀포시 강정동  1338',
#  '제주특별자치도 서귀포시 강정동  1545 샤모니리조트',
#  '제주특별자치도 서귀포시 강정동  162-1',
#  '제주특별자치도 서귀포시 강정동  164-1 호텔캘리포니아',
#  '제주특별자치도 서귀포시 강정동  173 호텔빠레브',
#  '제주특별자치도 서귀포시 강정동  173-1',
#  '제주특별자치도 서귀포시 강정동  173-3',
#  '제주특별자치도 서귀포시 강정동  1938 제주M리조트',
#  '제주특별자치도 서귀포시 강정동  2483-3',
#  '제주특별자치도 서귀포시 강정동  2498-3',
#  '제주특별자치도 서귀포시 강정동  2677 켄싱턴리조트',
#  '제주특별자치도 서귀포시 강정동  3447-1',
#  '제주특별자치도 서귀포시 강정동  3704 토스카나 가족호텔',
#  '제주특별자치도 서귀포시 강정동  855-1',
#  '제주특별자치도 서귀포시 남원읍 남원리 2390 금호콘도',
#  '제주특별자치도 서귀포시 남원읍 남원리 98-10',
#  '제주특별자치도 서귀포시 남원읍 위미리 2895',
#  '제주특별자치도 서귀포시 남원읍 위미리 4627',
#  '제주특별자치도 서귀포시 남원읍 위미리 4628',
#  '제주특별자치도 서귀포시 대정읍 안성리 214',
#  '제주특별자치도 서귀포시 대정읍 하모리 1021-2',
#  '제주특별자치도 서귀포시 대정읍 하모리 1089-23',
#  '제주특별자치도 서귀포시 대정읍 하모리 1414-1',
#  '제주특별자치도 서귀포시 대정읍 하모리 1414-6',
#  '제주특별자치도 서귀포시 대정읍 하모리 1502-1',
#  '제주특별자치도 서귀포시 대정읍 하모리 2129-1',
#  '제주특별자치도 서귀포시 대정읍 하모리 2129-3',
#  '제주특별자치도 서귀포시 대정읍 하모리 2133-5',
#  '제주특별자치도 서귀포시 대정읍 하모리 560-7',
#  '제주특별자치도 서귀포시 대포동  1181 케이디가족호텔',
#  '제주특별자치도 서귀포시 대포동  1695',
#  '제주특별자치도 서귀포시 대포동  1813',
#  '제주특별자치도 서귀포시 대포동  2079',
#  '제주특별자치도 서귀포시 대포동  2122',
#  '제주특별자치도 서귀포시 대포동  2538',
#  '제주특별자치도 서귀포시 동홍동  407-1',
#  '제주특별자치도 서귀포시 법환동  1452',
#  '제주특별자치도 서귀포시 법환동  1498',
#  '제주특별자치도 서귀포시 법환동  17 펠리시아',
#  '제주특별자치도 서귀포시 법환동  745-1 비스타케이호텔',
#  '제주특별자치도 서귀포시 법환동  745-2',
#  '제주특별자치도 서귀포시 법환동  745-5',
#  '제주특별자치도 서귀포시 법환동  745-6 블루오션시티',
#  '제주특별자치도 서귀포시 법환동  87-1 씨오르리조트',
#  '제주특별자치도 서귀포시 법환동  877-3 더 세리 리조트',
#  '제주특별자치도 서귀포시 법환동  978 폴에이리조트제주',
#  '제주특별자치도 서귀포시 보목동  1252-1 더베이 제주리조트',
#  '제주특별자치도 서귀포시 보목동  1453',
#  '제주특별자치도 서귀포시 상예동  185-1',
#  '제주특별자치도 서귀포시 상예동  625',
#  '제주특별자치도 서귀포시 상효동  2205',
#  '제주특별자치도 서귀포시 색달동  1188-1',
#  '제주특별자치도 서귀포시 색달동  1534',
#  '제주특별자치도 서귀포시 색달동  1622-2',
#  '제주특별자치도 서귀포시 색달동  1821-3 중문리조트',
#  '제주특별자치도 서귀포시 색달동  2101',
#  '제주특별자치도 서귀포시 색달동  2217',
#  '제주특별자치도 서귀포시 색달동  2284-1',
#  '제주특별자치도 서귀포시 색달동  2508 아리아호텔',
#  '제주특별자치도 서귀포시 색달동  2534-1 중문비치호스텔',
#  '제주특별자치도 서귀포시 색달동  2812-10 스위트호텔',
#  '제주특별자치도 서귀포시 색달동  2812-2 블룸호텔',
#  '제주특별자치도 서귀포시 색달동  2812-4 호텔롯데제주',
#  '제주특별자치도 서귀포시 색달동  2822-5 한국콘도',
#  '제주특별자치도 서귀포시 색달동  2864-32',
#  '제주특별자치도 서귀포시 색달동  301',
#  '제주특별자치도 서귀포시 색달동  3039-1',
#  '제주특별자치도 서귀포시 색달동  3039-3',
#  '제주특별자치도 서귀포시 서귀동  162-1 하워드존슨호텔 제주 서귀포 하버',
#  '제주특별자치도 서귀포시 서귀동  162-7',
#  '제주특별자치도 서귀포시 서귀동  182 글램블루호텔',
#  '제주특별자치도 서귀포시 서귀동  252-12',
#  '제주특별자치도 서귀포시 서귀동  255-1',
#  '제주특별자치도 서귀포시 서귀동  270-9',
#  '제주특별자치도 서귀포시 서귀동  289-13',
#  '제주특별자치도 서귀포시 서귀동  291-70',
#  '제주특별자치도 서귀포시 서귀동  294-6',
#  '제주특별자치도 서귀포시 서귀동  308-2 서귀포 가족호텔',
#  '제주특별자치도 서귀포시 서귀동  309-26 호텔펠리스텔콘',
#  '제주특별자치도 서귀포시 서귀동  314-2',
#  '제주특별자치도 서귀포시 서귀동  316-14 현영PALACE 가족호텔',
#  '제주특별자치도 서귀포시 서귀동  318-17 호텔 윈 스토리',
#  '제주특별자치도 서귀포시 서귀동  319-2 비스타케이호텔(천지연)',
#  '제주특별자치도 서귀포시 서귀동  325-1',
#  '제주특별자치도 서귀포시 서귀동  411-1 런 호텔',
#  '제주특별자치도 서귀포시 서귀동  432-3',
#  '제주특별자치도 서귀포시 서귀동  486-1 제주 서귀포 일성 트루엘',
#  '제주특별자치도 서귀포시 서귀동  494 유동오션펠리스',
#  '제주특별자치도 서귀포시 서귀동  536-2',
#  '제주특별자치도 서귀포시 서귀동  544-2 디 아일랜드 블루 오피스텔',
#  '제주특별자치도 서귀포시 서귀동  587-43',
#  '제주특별자치도 서귀포시 서귀동  626-2 아이리스호텔',
#  '제주특별자치도 서귀포시 서귀동  650-1',
#  '제주특별자치도 서귀포시 서귀동  685',
#  '제주특별자치도 서귀포시 서귀동  697-1',
#  '제주특별자치도 서귀포시 서귀동  776-1 파인힐호텔',
#  '제주특별자치도 서귀포시 서귀동  777-1 비케이호텔인제주',
#  '제주특별자치도 서귀포시 서귀동  782-3',
#  '제주특별자치도 서귀포시 서귀동  820-1',
#  '제주특별자치도 서귀포시 서귀동  829-5',
#  '제주특별자치도 서귀포시 서호동  115',
#  '제주특별자치도 서귀포시 서호동  1522-1',
#  '제주특별자치도 서귀포시 서호동  1522-2',
#  '제주특별자치도 서귀포시 서호동  1524-3',
#  '제주특별자치도 서귀포시 서호동  1524-7',
#  '제주특별자치도 서귀포시 서홍동  1253',
#  '제주특별자치도 서귀포시 서홍동  1289',
#  '제주특별자치도 서귀포시 서홍동  1777-3',
#  '제주특별자치도 서귀포시 서홍동  586',
#  '제주특별자치도 서귀포시 서홍동  637 파크 선샤인 제주',
#  '제주특별자치도 서귀포시 서홍동  637-3',
#  '제주특별자치도 서귀포시 성산읍 고성리 1090-16 아쿠아비치호텔',
#  '제주특별자치도 서귀포시 성산읍 고성리 1201 디아일랜드 마리나 호텔',
#  '제주특별자치도 서귀포시 성산읍 고성리 1204-4 동남토건',
#  '제주특별자치도 서귀포시 성산읍 고성리 127-2 휘닉스아일랜드콘도',
#  '제주특별자치도 서귀포시 성산읍 고성리 297-1 플레이스호텔',
#  '제주특별자치도 서귀포시 성산읍 고성리 298-5',
#  '제주특별자치도 서귀포시 성산읍 고성리 329-1 골든튤립제주성산호텔',
#  '제주특별자치도 서귀포시 성산읍 고성리 437-1',
#  '제주특별자치도 서귀포시 성산읍 고성리 496-2',
#  '제주특별자치도 서귀포시 성산읍 고성리 510-6',
#  '제주특별자치도 서귀포시 성산읍 고성리 514-1',
#  '제주특별자치도 서귀포시 성산읍 성산리 169-16',
#  '제주특별자치도 서귀포시 성산읍 성산리 180-5',
#  '제주특별자치도 서귀포시 성산읍 성산리 196-5 블루마운틴관광호텔',
#  '제주특별자치도 서귀포시 성산읍 성산리 234-19',
#  '제주특별자치도 서귀포시 성산읍 성산리 250',
#  '제주특별자치도 서귀포시 성산읍 성산리 308',
#  '제주특별자치도 서귀포시 성산읍 성산리 382-31',
#  '제주특별자치도 서귀포시 성산읍 성산리 382-6',
#  '제주특별자치도 서귀포시 성산읍 시흥리 10',
#  '제주특별자치도 서귀포시 성산읍 시흥리 200 더포그레이스호텔',
#  '제주특별자치도 서귀포시 성산읍 시흥리 205',
#  '제주특별자치도 서귀포시 성산읍 시흥리 208 봄그리고가을리조트',
#  '제주특별자치도 서귀포시 성산읍 시흥리 5',
#  '제주특별자치도 서귀포시 성산읍 신산리 1176-9',
#  '제주특별자치도 서귀포시 성산읍 신산리 1181 비치캐슬',
#  '제주특별자치도 서귀포시 성산읍 신산리 317 오션 갤러리 프리미어 빌라스 3단지',
#  '제주특별자치도 서귀포시 성산읍 신산리 51 오션 갤러리 프리미어 빌라스 2단지',
#  '제주특별자치도 서귀포시 성산읍 오조리 941-1 코델리아리조트',
#  '제주특별자치도 서귀포시 성산읍 오조리 990-1',
#  '제주특별자치도 서귀포시 성산읍 온평리 1832-1 휴리조트',
#  '제주특별자치도 서귀포시 성산읍 온평리 648-2',
#  '제주특별자치도 서귀포시 신효동  506-9',
#  '제주특별자치도 서귀포시 신효동  898',
#  '제주특별자치도 서귀포시 안덕면 사계리 1586-1',
#  '제주특별자치도 서귀포시 안덕면 사계리 2166-3',
#  '제주특별자치도 서귀포시 안덕면 사계리 2266-1',
#  '제주특별자치도 서귀포시 안덕면 사계리 2763-4',
#  '제주특별자치도 서귀포시 안덕면 사계리 3318-1',
#  '제주특별자치도 서귀포시 안덕면 사계리 734',
#  '제주특별자치도 서귀포시 안덕면 상창리 2893',
#  '제주특별자치도 서귀포시 안덕면 상천리 산78-1 루체빌리조트',
#  '제주특별자치도 서귀포시 안덕면 서광리 산24',
#  '제주특별자치도 서귀포시 안덕면 서광리 산24-15',
#  '제주특별자치도 서귀포시 안덕면 서광리 산35-16',
#  '제주특별자치도 서귀포시 안덕면 서광리 산41 제주항공우주호텔',
#  '제주특별자치도 서귀포시 안덕면 창천리 907-1',
#  '제주특별자치도 서귀포시 안덕면 화순리 1066-3',
#  '제주특별자치도 서귀포시 안덕면 화순리 1084',
#  '제주특별자치도 서귀포시 안덕면 화순리 1888 Y RESORT',
#  '제주특별자치도 서귀포시 영남동  224 제주아이브',
#  '제주특별자치도 서귀포시 중문동  2050-1',
#  '제주특별자치도 서귀포시 중문동  2115-1',
#  '제주특별자치도 서귀포시 중문동  2129-2',
#  '제주특별자치도 서귀포시 중문동  2161-2',
#  '제주특별자치도 서귀포시 중문동  2167-16',
#  '제주특별자치도 서귀포시 중문동  2453 중문썬라이즈호스텔',
#  '제주특별자치도 서귀포시 중문동  2563-1',
#  '제주특별자치도 서귀포시 중문동  2700-2 부영호텔',
#  '제주특별자치도 서귀포시 토평동  237-2',
#  '제주특별자치도 서귀포시 토평동  2869',
#  '제주특별자치도 서귀포시 토평동  486-3 칼호텔',
#  '제주특별자치도 서귀포시 토평동  산30-13',
#  '제주특별자치도 서귀포시 표선면 토산리 17',
#  '제주특별자치도 서귀포시 표선면 표선리 40-69',
#  '제주특별자치도 서귀포시 표선면 표선리 591-1',
#  '제주특별자치도 서귀포시 하예동  1793',
#  '제주특별자치도 서귀포시 하예동  1795-1',
#  '제주특별자치도 서귀포시 하예동  1888 베이힐풀&빌라',
#  '제주특별자치도 서귀포시 하예동  460-1',
#  '제주특별자치도 서귀포시 호근동  1591',
#  '제주특별자치도 서귀포시 호근동  1591-2',
#  '제주특별자치도 서귀포시 호근동  1638-2 팜빌리지',
#  '제주특별자치도 서귀포시 호근동  479-4',
#  '제주특별자치도 서귀포시 회수동  30 위(WE)호텔',
#  '제주특별자치도 서귀포시 회수동  659 일레호텔',
#  '제주특별자치도 제주시 건입동  1037-1',
#  '제주특별자치도 제주시 건입동  1443 호텔리젠트마린더블루',
#  '제주특별자치도 제주시 건입동  1443-2 호텔 휘슬',
#  '제주특별자치도 제주시 건입동  658-1 다이아나호텔',
#  '제주특별자치도 제주시 구좌읍 동복리 1652-2',
#  '제주특별자치도 제주시 구좌읍 동복리 827',
#  '제주특별자치도 제주시 구좌읍 평대리 3347-3',
#  '제주특별자치도 제주시 구좌읍 하도리 2999-1',
#  '제주특별자치도 제주시 내도동  104',
#  '제주특별자치도 제주시 내도동  15-1 씨앤 관광호텔',
#  '제주특별자치도 제주시 내도동  239-1',
#  '제주특별자치도 제주시 내도동  277-1 제주인관광호텔',
#  '제주특별자치도 제주시 노형동  1288-4',
#  '제주특별자치도 제주시 노형동  1295-16 베스트웨스턴 가족호텔 제주',
#  '제주특별자치도 제주시 노형동  2488-1',
#  '제주특별자치도 제주시 노형동  310-2',
#  '제주특별자치도 제주시 노형동  912-12 메이플호텔',
#  '제주특별자치도 제주시 노형동  912-3 제주아이비호텔',
#  '제주특별자치도 제주시 노형동  914',
#  '제주특별자치도 제주시 노형동  917-8',
#  '제주특별자치도 제주시 노형동  925 제주 드림타워 복합리조트',
#  '제주특별자치도 제주시 노형동  928-3',
#  '제주특별자치도 제주시 노형동  930-5',
#  '제주특별자치도 제주시 도두이동  1644-4',
#  '제주특별자치도 제주시 도두일동  1742 제주아모렉스가족호텔',
#  '제주특별자치도 제주시 도두일동  1750 해든호텔',
#  '제주특별자치도 제주시 도두일동  2272-2 에스관광호텔',
#  '제주특별자치도 제주시 삼도이동  1053-15',
#  '제주특별자치도 제주시 삼도이동  1088-1',
#  '제주특별자치도 제주시 삼도이동  1179-8',
#  '제주특별자치도 제주시 삼도이동  1183-2',
#  '제주특별자치도 제주시 삼도이동  1192-18 제주팔레스관광호텔',
#  '제주특별자치도 제주시 삼도이동  1197 제주오리엔탈호텔',
#  '제주특별자치도 제주시 삼도이동  1244-4',
#  '제주특별자치도 제주시 삼도이동  1254 라마다프라자호텔',
#  '제주특별자치도 제주시 삼도이동  1260-1 오션스위츠 제주호텔',
#  '제주특별자치도 제주시 삼도이동  149-4',
#  '제주특별자치도 제주시 삼도이동  228-32',
#  '제주특별자치도 제주시 삼도이동  57-2',
#  '제주특별자치도 제주시 삼도이동  914',
#  '제주특별자치도 제주시 삼도일동  531',
#  '제주특별자치도 제주시 삼도일동  534-13',
#  '제주특별자치도 제주시 삼도일동  535-10 ASTAR HOTEL',
#  '제주특별자치도 제주시 삼도일동  552-16',
#  '제주특별자치도 제주시 삼도일동  558-5 알리바호텔',
#  '제주특별자치도 제주시 삼도일동  559-10',
#  '제주특별자치도 제주시 삼도일동  710-8',
#  '제주특별자치도 제주시 삼도일동  751-8',
#  '제주특별자치도 제주시 삼양이동  2140-1',
#  '제주특별자치도 제주시 삼양이동  2140-2 삼미하이츠빌라',
#  '제주특별자치도 제주시 애월읍 고내리 1105-1',
#  '제주특별자치도 제주시 애월읍 고내리 300-1',
#  '제주특별자치도 제주시 애월읍 고내리 332-5',
#  '제주특별자치도 제주시 애월읍 고내리 365-2 빌레리조트',
#  '제주특별자치도 제주시 애월읍 고내리 41',
#  '제주특별자치도 제주시 애월읍 고내리 77-4',
#  '제주특별자치도 제주시 애월읍 고내리 79-8',
#  '제주특별자치도 제주시 애월읍 고내리 84',
#  '제주특별자치도 제주시 애월읍 고성리 880',
#  '제주특별자치도 제주시 애월읍 고성리 980',
#  '제주특별자치도 제주시 애월읍 곽지리 1565-18 마레보비치호텔',
#  '제주특별자치도 제주시 애월읍 곽지리 1581-15',
#  '제주특별자치도 제주시 애월읍 광령리 2807-3 UTS골프빌리지',
#  '제주특별자치도 제주시 애월읍 광령리 2863-2 스타하우스',
#  '제주특별자치도 제주시 애월읍 구엄리 1216',
#  '제주특별자치도 제주시 애월읍 구엄리 609-1 동양콘도미니엄',
#  '제주특별자치도 제주시 애월읍 구엄리 941 구엄리 리조트',
#  '제주특별자치도 제주시 애월읍 금성리 472-13',
#  '제주특별자치도 제주시 애월읍 신엄리 2734-1 오렌지힐',
#  '제주특별자치도 제주시 애월읍 신엄리 2735-1',
#  '제주특별자치도 제주시 애월읍 신엄리 2736-1',
#  '제주특별자치도 제주시 애월읍 신엄리 2768-7',
#  '제주특별자치도 제주시 애월읍 신엄리 2808',
#  '제주특별자치도 제주시 애월읍 신엄리 2946-4',
#  '제주특별자치도 제주시 애월읍 신엄리 920 에뜨왈호텔',
#  '제주특별자치도 제주시 애월읍 애월리 2505 제주토비스콘도',
#  '제주특별자치도 제주시 애월읍 하가리 1256-2',
#  '제주특별자치도 제주시 애월읍 하귀1리 544-2',
#  '제주특별자치도 제주시 애월읍 하귀2리 2615-7 시드니호텔',
#  '제주특별자치도 제주시 애월읍 하귀2리 2615-8',
#  '제주특별자치도 제주시 애월읍 하귀2리 2732',
#  '제주특별자치도 제주시 애월읍 하귀2리 2749-3 나비스호텔',
#  '제주특별자치도 제주시 애월읍 하귀2리 2869-10',
#  '제주특별자치도 제주시 연동  1487-1',
#  '제주특별자치도 제주시 연동  2324-6 제주연동 롯데시티호텔',
#  '제주특별자치도 제주시 연동  2334-4',
#  '제주특별자치도 제주시 연동  251-1 엠버서더 관광호텔',
#  '제주특별자치도 제주시 연동  251-29 맨하탄호텔',
#  '제주특별자치도 제주시 연동  251-41',
#  '제주특별자치도 제주시 연동  251-62',
#  '제주특별자치도 제주시 연동  251-79 K.E관광호텔',
#  '제주특별자치도 제주시 연동  253-3',
#  '제주특별자치도 제주시 연동  260-25 제주에어포트호텔',
#  '제주특별자치도 제주시 연동  260-45',
#  '제주특별자치도 제주시 연동  260-9',
#  '제주특별자치도 제주시 연동  261-25 HOTEL LEO',
#  '제주특별자치도 제주시 연동  261-3',
#  '제주특별자치도 제주시 연동  261-37',
#  '제주특별자치도 제주시 연동  261-67 MJ호스텔',
#  '제주특별자치도 제주시 연동  263-12 뉴아일랜드관광호텔',
#  '제주특별자치도 제주시 연동  263-15 메종글래드 제주',
#  '제주특별자치도 제주시 연동  263-2 제주1번가 더테라스',
#  '제주특별자치도 제주시 연동  268',
#  '제주특별자치도 제주시 연동  269-1 썬랜드호텔',
#  '제주특별자치도 제주시 연동  270-1 파크사이드호텔',
#  '제주특별자치도 제주시 연동  270-2 신신호텔 제주공항',
#  '제주특별자치도 제주시 연동  271-23 J2가족호텔',
#  '제주특별자치도 제주시 연동  271-4',
#  '제주특별자치도 제주시 연동  272-26',
#  '제주특별자치도 제주시 연동  272-29',
#  '제주특별자치도 제주시 연동  272-34 제주로얄호텔',
#  '제주특별자치도 제주시 연동  272-50',
#  '제주특별자치도 제주시 연동  273-36',
#  '제주특별자치도 제주시 연동  273-54',
#  '제주특별자치도 제주시 연동  273-55',
#  '제주특별자치도 제주시 연동  274-16 SHILLA STAY JEJU HOTEL',
#  '제주특별자치도 제주시 연동  277-1 제주펄호텔',
#  '제주특별자치도 제주시 연동  278-1',
#  '제주특별자치도 제주시 연동  278-8',
#  '제주특별자치도 제주시 연동  279-3',
#  '제주특별자치도 제주시 연동  281-22',
#  '제주특별자치도 제주시 연동  282-3 호텔에어시티제주',
#  '제주특별자치도 제주시 연동  284-46 센트럴호텔',
#  '제주특별자치도 제주시 연동  284-6',
#  '제주특별자치도 제주시 연동  284-8 컬리넌관광호텔',
#  '제주특별자치도 제주시 연동  284-9',
#  '제주특별자치도 제주시 연동  290-1 성남빌라',
#  '제주특별자치도 제주시 연동  290-3',
#  '제주특별자치도 제주시 연동  291-14 블루스카이',
#  '제주특별자치도 제주시 연동  292-17',
#  '제주특별자치도 제주시 연동  292-27',
#  '제주특별자치도 제주시 연동  292-32',
#  '제주특별자치도 제주시 연동  292-38',
#  '제주특별자치도 제주시 연동  300-4',
#  '제주특별자치도 제주시 연동  300-8',
#  '제주특별자치도 제주시 연동  306-14 아이진호텔',
#  '제주특별자치도 제주시 오등동  10-1',
#  '제주특별자치도 제주시 오라이동  3100-1',
#  '제주특별자치도 제주시 외도일동  401-8',
#  '제주특별자치도 제주시 용담삼동  1020-4',
#  '제주특별자치도 제주시 용담삼동  2383-1',
#  '제주특별자치도 제주시 용담삼동  2389 로긴가족호텔',
#  '제주특별자치도 제주시 용담삼동  2398 오슬로관광호텔',
#  '제주특별자치도 제주시 용담삼동  2555 ciel bleu 호텔',
#  '제주특별자치도 제주시 용담삼동  2572-4 화이트하우스',
#  '제주특별자치도 제주시 용담이동  1783-1',
#  '제주특별자치도 제주시 용담이동  2761',
#  '제주특별자치도 제주시 용담일동  137-4',
#  '제주특별자치도 제주시 용담일동  159-1 제주퍼시픽호텔',
#  '제주특별자치도 제주시 용담일동  183-2 제주캘럭시호텔',
#  '제주특별자치도 제주시 용담일동  2578-2',
#  '제주특별자치도 제주시 우도면 연평리 1707',
#  '제주특별자치도 제주시 이도이동  1025-8',
#  '제주특별자치도 제주시 이도이동  1061-5',
#  '제주특별자치도 제주시 이도이동  1139-3',
#  '제주특별자치도 제주시 이도이동  1174-1 호텔샬롬',
#  '제주특별자치도 제주시 이도이동  1776-31',
#  '제주특별자치도 제주시 이도일동  1244-7 애플관광호텔',
#  '제주특별자치도 제주시 이호일동  345',
#  '제주특별자치도 제주시 이호일동  363 비스타리조트',
#  '제주특별자치도 제주시 이호일동  365 스완지호스텔',
#  '제주특별자치도 제주시 일도일동  1323-1',
#  '제주특별자치도 제주시 조천읍 대흘리 1089-12',
#  '제주특별자치도 제주시 조천읍 대흘리 1089-8',
#  '제주특별자치도 제주시 조천읍 대흘리 1221-1',
#  '제주특별자치도 제주시 조천읍 함덕리 1010 제주비치',
#  '제주특별자치도 제주시 조천읍 함덕리 1252-10',
#  '제주특별자치도 제주시 조천읍 함덕리 1252-55 오션그랜드제주호텔',
#  '제주특별자치도 제주시 조천읍 함덕리 1269-19 골든튤립제주함덕호텔',
#  '제주특별자치도 제주시 조천읍 함덕리 1269-9 유탑유블레스호텔',
#  '제주특별자치도 제주시 조천읍 함덕리 274 대명리조트',
#  '제주특별자치도 제주시 조천읍 함덕리 3061 제주 함덕 라마다호텔',
#  '제주특별자치도 제주시 조천읍 함덕리 3230-1',
#  '제주특별자치도 제주시 한경면 두모리 27',
#  '제주특별자치도 제주시 한경면 판포리 1684',
#  '제주특별자치도 제주시 한경면 판포리 2872 메가리조트',
#  '제주특별자치도 제주시 한림읍 귀덕리 1502',
#  '제주특별자치도 제주시 한림읍 귀덕리 3646',
#  '제주특별자치도 제주시 한림읍 귀덕리 3861 켄싱턴리조트',
#  '제주특별자치도 제주시 한림읍 귀덕리 721-1',
#  '제주특별자치도 제주시 한림읍 금능리 1258',
#  '제주특별자치도 제주시 한림읍 금능리 1625 일성비치콘도미니엄',
#  '제주특별자치도 제주시 한림읍 금능리 1803-2',
#  '제주특별자치도 제주시 한림읍 금능리 2005',
#  '제주특별자치도 제주시 한림읍 금능리 2005-1',
#  '제주특별자치도 제주시 한림읍 금악리 3399',
#  '제주특별자치도 제주시 한림읍 금악리 산32-1 아덴힐CC',
#  '제주특별자치도 제주시 한림읍 옹포리 392-1',
#  '제주특별자치도 제주시 한림읍 옹포리 393-16',
#  '제주특별자치도 제주시 한림읍 월령리 254-1',
#  '제주특별자치도 제주시 한림읍 한림리 1587',
#  '제주특별자치도 제주시 한림읍 협재리 1165',
#  '제주특별자치도 제주시 한림읍 협재리 1193 한림리조트',
#  '제주특별자치도 제주시 한림읍 협재리 1398',
#  '제주특별자치도 제주시 한림읍 협재리 1607 선유빌딩',
#  '제주특별자치도 제주시 한림읍 협재리 2021-1',
#  '제주특별자치도 제주시 한림읍 협재리 2514-2',
#  '제주특별자치도 제주시 한림읍 협재리 2838',
#  '제주특별자치도 제주시 한림읍 협재리 876-3',
#  '제주특별자치도 제주시 한림읍 협재리 964-1 하모니',
#  '제주특별자치도 제주시 해안동  2101-3',
#  '제주특별자치도 제주시 해안동  2109',
#  '제주특별자치도 제주시 해안동  2131-1 가족호텔펄리',
#  '제주특별자치도 제주시 해안동  2499-2',
#  '제주특별자치도 제주시 회천동  3-16 한화리조트']

# %%
# 순서를 유지하고 중복을 제거하는 함수
# def delete_duplicated(names):
#   duplicated_name = []
#   for i in names:
#     if(i not in duplicated_name):
#       duplicated_name.append(i)
#   return duplicated_name

# %%
list_name =[]#여러 이름을 갖는 호텔들의 리스트
for i in range(len(list_addr)):
  hotel_name = df_hotel[df_hotel['addr'] == list_addr[i]]['name']
  duplicated_name = list(set(hotel_name)) # 순서를 유지하고 싶을 경우 위의 함수를 사용
  if(len(duplicated_name)>1): # 이름값이 두개이상있는 호텔을 list_name에 저장
    list_name.append(duplicated_name)

  
list_name
# Out:
# []

# %%
for i in range(len(list_name)):
  df_hotel.loc[df_hotel['name'] == list_name[i][0],'name'] = list_name[i][1]
  # loc함수를 통해 두 조건에 맞는 열을 지정
  # 선택된 호텔의 이름을 통일화 시킨다

# 3사이트에서 각기 다른 이름을 사용하는 경우도 있기 때문에 list_name이 빈 리스트가 될때까지 반복한다. 
# 아래와같이 while문 사용시, 한번에 끝낼 수 있다
# Out:
#       Unnamed: 0   name                                        review  \
# 1099        1099  빠레브호텔                             뷰도 좋고 친절하셔서 좋았습니다
# 1100        1100  빠레브호텔              주차시설이부족한고 난방이히터라 건조합니다\n그외 만족합니다
# 1101        1101  빠레브호텔  전체적으로 조용하고 좋았어요. 조식뷔페도 아침에 부담없이 먹을수 있어서 좋았어요
# 1102        1102  빠레브호텔                                  방에 냄새가 너무나요.
# 1103        1103  빠레브호텔                           가격대비 너무 만족! 직원들 친절!
# ...          ...    ...                                           ...
# 3635        3635  빠레브호텔                                   가격대비 짱!!!!!
# 3636        3636  빠레브호텔  호텔컨디선 가격대비 최고입니다~\n깨끗하고 아주 만족해요 엄마모시고 다시올꺼에요
# 3637        3637  빠레브호텔                            좋은 숙소라 1박 더 했습니다~!
# 3638        3638  빠레브호텔                           자주 이용하는데 늘 너무 좋습니다~
# 3639        3639  빠레브호텔                        공항에서는  좀 멀었지만 깨끗하고  강추
#
#                              addr    site
# 1099  제주특별자치도 서귀포시 강정동  173 호텔빠레브  데일리 호텔
# 1100  제주특별자치도 서귀포시 강정동  173 호텔빠레브  데일리 호텔
# 1101  제주특별자치도 서귀포시 강정동  173 호텔빠레브  데일리 호텔
# 1102  제주특별자치도 서귀포시 강정동  173 호텔빠레브  데일리 호텔
# 1103  제주특별자치도 서귀포시 강정동  173 호텔빠레브  데일리 호텔
# ...                           ...     ...
# 3635  제주특별자치도 서귀포시 강정동  173 호텔빠레브  데일리 호텔
# 3636  제주특별자치도 서귀포시 강정동  173 호텔빠레브  데일리 호텔
# 3637  제주특별자치도 서귀포시 강정동  173 호텔빠레브  데일리 호텔
# 3638  제주특별자치도 서귀포시 강정동  173 호텔빠레브  데일리 호텔
# 3639  제주특별자치도 서귀포시 강정동  173 호텔빠레브  데일리 호텔
#
# [2541 rows x 5 columns]

# %%
n= 1
while(n):
    list_name =[]
    for i in range(len(list_addr)):
      hotel_name = df_hotel[df_hotel['addr'] == list_addr[i]]['name']
      duplicated_name = list(set(hotel_name)) # 순서를 유지하고 싶을 경우 위의 함수를 사용
      if(len(duplicated_name)>1):
        list_name.append(duplicated_name)
    for i in range(len(list_name)):
      df_hotel.loc[df_hotel['name'] == list_name[i][0],'name'] = list_name[i][1]
    n=len(list_name)

# %%
df_hotel[df_hotel['name'] == '윈스토리 호텔 서귀포']
# Out:
#        Unnamed: 0         name  \
# 43065       43065  윈스토리 호텔 서귀포
# 43066       43066  윈스토리 호텔 서귀포
# 43067       43067  윈스토리 호텔 서귀포
# 43068       43068  윈스토리 호텔 서귀포
# 43069       43069  윈스토리 호텔 서귀포
# ...           ...          ...
# 46776       46776  윈스토리 호텔 서귀포
# 46777       46777  윈스토리 호텔 서귀포
# 46778       46778  윈스토리 호텔 서귀포
# 46779       46779  윈스토리 호텔 서귀포
# 46780       46780  윈스토리 호텔 서귀포
#
#                                                   review  \
# 43065                                   괜찮았습니다 조식은 조금 실망
# 43066                            치약은 무료로 준비해주시면 좋았을거 같아요
# 43067  다 좋았는데 방안의 에어컨이 작동하면 너무 시끄러웠던것 같아요 그것 빼곤 다 만족합...
# 43068                      침구류도 깨끗하고 침대도 푹신하고 너무 잘쉬다가요^^
# 43069                                  방도깨끗하고 직원분들도 친절굳굳
# ...                                                  ...
# 46776  새건물 이라 좋았음...프론트도 웃으면서 맞아주시고....편의점 1층에 바로 있고 ...
# 46777  시설 정말 만족했어요.\n안에 전자레인지 냉장고 작은 씽크대 심지어 드럼 세탁기도 ...
# 46778  1. 서귀포시내에 위치해 있어 접근성이 좋습니다.\n2. 실내 인테리어가 깔끔합니다...
# 46779                                  진심 최고입니다. 꼭 오세요 !
# 46780        엄청 깨끗하고 서비스도 잘해주셔서 전혀 불편함없이 편하게 2박 보냈습니다~^^
#
#                                     addr    site
# 43065            제주특별자치도 서귀포시 서귀동  294-6  데일리 호텔
# 43066            제주특별자치도 서귀포시 서귀동  294-6  데일리 호텔
# 43067            제주특별자치도 서귀포시 서귀동  294-6  데일리 호텔
# 43068            제주특별자치도 서귀포시 서귀동  294-6  데일리 호텔
# 43069            제주특별자치도 서귀포시 서귀동  294-6  데일리 호텔
# ...                                  ...     ...
# 46776  제주특별자치도 서귀포시 서귀동  318-17 호텔 윈 스토리    여기어때
# 46777  제주특별자치도 서귀포시 서귀동  318-17 호텔 윈 스토리    여기어때
# 46778  제주특별자치도 서귀포시 서귀동  318-17 호텔 윈 스토리    여기어때
# 46779  제주특별자치도 서귀포시 서귀동  318-17 호텔 윈 스토리    여기어때
# 46780  제주특별자치도 서귀포시 서귀동  318-17 호텔 윈 스토리    여기어때
#
# [2614 rows x 5 columns]

# %%
df_hotel.to_csv('최종리뷰.csv', encoding='utf-8-sig')
